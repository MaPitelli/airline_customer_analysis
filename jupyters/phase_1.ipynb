# %% [markdown]
# ## Fase 1: Exploración y Limpieza
#
# 1. Exploración Inicial:
#     * Realiza una exploración inicial de los datos para identificar posibles problemas, como valores nulos, atípicos o datos faltantes en las columnas relevantes.
#     * Utiliza funciones de Pandas para obtener información sobre la estructura de los datos, la presencia de valores nulos y estadísticas básicas de las columnas involucradas.
#     * Une los dos conjuntos de datos de la forma más eficiente.
#
# 2. LimpiezadeDatos:
#     * Elimina o trata los valores nulos, si los hay, en las columnas clave para asegurar que los datos estén completos. Verifica la consistencia y corrección de los datos para asegurarte de que los datos se presenten de forma coherente.
#     * Realiza cualquier ajuste o conversión necesaria en las columnas (por ejemplo, cambiar tipos de datos) para garantizar la adecuación de los datos para el análisis estadístico.

# %% [markdown]
# ### importamos las librerías que necesitamos

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Exploración Inicial

# %%
# Cargamos los datos con el método read_csv de pandas y guardamos los objetos de tipo DataFrame en variables 
df_activity = pd.read_csv('../data/Customer Flight Activity.csv')
df_history = pd.read_csv('../data/Customer Loyalty History.csv')

# %%
# Usamos el método info de pandas para ver el total de filas y columnas en el dataframe, la cantidad de valores no nulos y el tipo de dato por columna.
df_activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %%
# Creamos un diccionario para cambiar los nombres de las columnas
col_names_activity = {col:col.lower().replace(' ', '_') for col in df_activity.columns}
col_names_activity
# Out:
# {'Loyalty Number': 'loyalty_number',
#  'Year': 'year',
#  'Month': 'month',
#  'Flights Booked': 'flights_booked',
#  'Flights with Companions': 'flights_with_companions',
#  'Total Flights': 'total_flights',
#  'Distance': 'distance',
#  'Points Accumulated': 'points_accumulated',
#  'Points Redeemed': 'points_redeemed',
#  'Dollar Cost Points Redeemed': 'dollar_cost_points_redeemed'}

# %%
df_history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16737 entries, 0 to 16736
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loyalty Number      16737 non-null  int64
#  1   Country             16737 non-null  object
#  2   Province            16737 non-null  object
#  3   City                16737 non-null  object
#  4   Postal Code         16737 non-null  object
#  5   Gender              16737 non-null  object
#  6   Education           16737 non-null  object
#  7   Salary              12499 non-null  float64
#  8   Marital Status      16737 non-null  object
#  9   Loyalty Card        16737 non-null  object
#  10  CLV                 16737 non-null  float64
#  11  Enrollment Type     16737 non-null  object
#  12  Enrollment Year     16737 non-null  int64
#  13  Enrollment Month    16737 non-null  int64
#  14  Cancellation Year   2067 non-null   float64
#  15  Cancellation Month  2067 non-null   float64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 2.0+ MB

# %%
col_names_history = {col:col.lower().replace(' ', '_') for col in df_history.columns}
col_names_history
# Out:
# {'Loyalty Number': 'loyalty_number',
#  'Country': 'country',
#  'Province': 'province',
#  'City': 'city',
#  'Postal Code': 'postal_code',
#  'Gender': 'gender',
#  'Education': 'education',
#  'Salary': 'salary',
#  'Marital Status': 'marital_status',
#  'Loyalty Card': 'loyalty_card',
#  'CLV': 'clv',
#  'Enrollment Type': 'enrollment_type',
#  'Enrollment Year': 'enrollment_year',
#  'Enrollment Month': 'enrollment_month',
#  'Cancellation Year': 'cancellation_year',
#  'Cancellation Month': 'cancellation_month'}

# %%
# Con el método rename de Pandas renombramos las columnas usando los diccionarios creados previamente
df_activity.rename(columns = col_names_activity, inplace = True)
df_history.rename(columns = col_names_history, inplace = True) # El inplace es un parámetro que altera el DataFrame original

# %%
# El método head nos permite ver las primeras 5 filas del DataFrame
df_activity.head()
# Out:
#    loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    total_flights  distance  points_accumulated  points_redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    dollar_cost_points_redeemed
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0

# %%
df_history.head()
# Out:
#    loyalty_number country          province       city postal_code  gender  \
# 0          480934  Canada           Ontario    Toronto     M2Z 4K1  Female
# 1          549612  Canada           Alberta   Edmonton     T3G 6Y6    Male
# 2          429460  Canada  British Columbia  Vancouver     V6E 3D9    Male
# 3          608370  Canada           Ontario    Toronto     P1W 1K4    Male
# 4          530508  Canada            Quebec       Hull     J8Y 3Z5    Male
#
#   education    salary marital_status loyalty_card      clv enrollment_type  \
# 0  Bachelor   83236.0        Married         Star  3839.14        Standard
# 1   College       NaN       Divorced         Star  3839.61        Standard
# 2   College       NaN         Single         Star  3839.75        Standard
# 3   College       NaN         Single         Star  3839.75        Standard
# 4  Bachelor  103495.0        Married         Star  3842.79        Standard
#
#    enrollment_year  enrollment_month  cancellation_year  cancellation_month
# 0             2016                 2                NaN                 NaN
# 1             2016                 3                NaN                 NaN
# 2             2014                 7             2018.0                 1.0
# 3             2013                 2                NaN                 NaN
# 4             2014                10                NaN                 NaN

# %%
# El método describe nos permite ver las estadísticas descriptivas de las variables numéricas del DataFrame
df_activity.describe().T # La 'T' de transpose cambia las filas y columnas
# Out:
#                                 count           mean            std       min  \
# loyalty_number               405624.0  550037.873084  258935.286969  100018.0
# year                         405624.0    2017.500000       0.500001    2017.0
# month                        405624.0       6.500000       3.452057       1.0
# flights_booked               405624.0       4.115052       5.225518       0.0
# flights_with_companions      405624.0       1.031805       2.076869       0.0
# total_flights                405624.0       5.146858       6.521227       0.0
# distance                     405624.0    1208.880059    1433.155320       0.0
# points_accumulated           405624.0     123.692721     146.599831       0.0
# points_redeemed              405624.0      30.696872     125.486049       0.0
# dollar_cost_points_redeemed  405624.0       2.484503      10.150038       0.0
#
#                                    25%       50%        75%       max
# loyalty_number               326961.00  550834.0  772194.00  999986.0
# year                           2017.00    2017.5    2018.00    2018.0
# month                             3.75       6.5       9.25      12.0
# flights_booked                    0.00       1.0       8.00      21.0
# flights_with_companions           0.00       0.0       1.00      11.0
# total_flights                     0.00       1.0      10.00      32.0
# distance                          0.00     488.0    2336.00    6293.0
# points_accumulated                0.00      50.0     239.00     676.5
# points_redeemed                   0.00       0.0       0.00     876.0
# dollar_cost_points_redeemed       0.00       0.0       0.00      71.0

# %% [markdown]
# ### Conclusiones que podemos extraer del describe para el conjunto de datos activity:
#
# * El loyalty_number va de 100018.0 a 999986.0 y hay un total de 405624.0 loyalty_number.
# * Los años van de 2017 a 2108 y los meses de 1 a 12.
# * La cantidad mas alta de flights_booked es de 21.0 y un 50% de los datos está por debajo de 1 flights_booked.
# * la cantidad mas alta de flights_with_companions es de 11.0 y un 75% de los datos está por debajo de 1 flights_with_companions.
# * La cantidad mas alta de total_flights es de 32.0 y un 50% de los datos está por debajo de 1 total_flights.
# * La distancia mas alta es de 6293.0 y un 50% de los datos tiene la distancia inferior a 488.
# * La cantidad mas alta de points_accumulated es de 676.5 y un 50% de los datos es inferior a 50.0 points_accumulated.
# * La cantidad mas alta de points_redeemed es de 876.0 y un 75% de los datos es inferior a 0 points_redeemed.
# * La cantidad mas alta de dollar_cost_points_redeemed es de 71.0 y un 75% de los datos es inferior a 0 dollar_cost_points_redeemed.
#
# ### Los tipos de datos son coherentes y no hay valores nulos.

# %%
df_history.describe().T
# Out:
#                       count           mean            std        min  \
# loyalty_number      16737.0  549735.880445  258912.132453  100018.00
# salary              12499.0   79245.609409   35008.297285  -58486.00
# clv                 16737.0    7988.896536    6860.982280    1898.01
# enrollment_year     16737.0    2015.253211       1.979111    2012.00
# enrollment_month    16737.0       6.669116       3.398958       1.00
# cancellation_year    2067.0    2016.503145       1.380743    2013.00
# cancellation_month   2067.0       6.962748       3.455297       1.00
#
#                           25%        50%        75%        max
# loyalty_number      326603.00  550434.00  772019.00  999986.00
# salary               59246.50   73455.00   88517.50  407228.00
# clv                   3980.84    5780.18    8940.58   83325.38
# enrollment_year       2014.00    2015.00    2017.00    2018.00
# enrollment_month         4.00       7.00      10.00      12.00
# cancellation_year     2016.00    2017.00    2018.00    2018.00
# cancellation_month       4.00       7.00      10.00      12.00

# %% [markdown]
# ### Conclusiones que podemos extraer del describe para el conjunto de datos history:
#
# * El loyalty_number va de 100018.0 a 999986.0 y hay un total de 16737.0 loyalty_number.
# * El salary tiene un conteo de 12499 valores, indicando que hay valores nulos, que también se pueden observar en el info(). El valor mínimo es negativo y el máximo es 407228.
# * El clv va de 1898.01 a 83325.38 y un 50% de los datos son inferiores a 5780.18.
# * El enrollment_year va de 2012 a 2018 y un 50% de los datos es inferior a 2015.
# * El enrollment_month va de 1 a 12 y un 50% de los datos es inferior a 7.
# * El cancellation_year va de 2013 a 2018 y un 50% de los datos es inferior a 2017. El conteo indica que hay valores nulos, lo que puede significar que estos clientes con valores nulos no han cancelado el plan de fidelidad.
# * El cancellation_month va de 1 a 12 y un 50% de los datos es inferior a 7. El conteo es igual que el cancellation year, lo que probablemente indica que los valores que hay representan los clientes que han cancelado el plan de fidelidad.

# %% [markdown]
# Intentaremos confirmar suposiciones iniciales hechas a partir del describe

# %%
df_history[df_history.salary < 0].shape[0] # Usando el filtrado y el shape podemos ver que hay 20 valores negativos en la columna salary.
# Out:
# 20

# %% [markdown]
# Tras verificar que los rangos de los salaries son compatibles con los demás rangos del conjunto de datos, interpretamos que esto ha sido un error a la hora de insertar estos datos.
# Al tratarse de 20 valores en mas de 12 mil, los convertiremos a valores absolutos.

# %%
df_history[df_history.salary < 0]['salary']
# Out:
# 1082    -49830.0
# 1894    -12497.0
# 2471    -46683.0
# 3575    -45962.0
# 3932    -19325.0
# 4712    -43234.0
# 6560    -10605.0
# 6570    -17534.0
# 7373    -58486.0
# 8576    -31911.0
# 8767    -49001.0
# 10232   -34079.0
# 11635    -9081.0
# 12596   -46470.0
# 13564   -26322.0
# 14327   -47310.0
# 14355   -39503.0
# 15416   -19332.0
# 16431   -46303.0
# 16735   -57297.0
# Name: salary, dtype: float64

# %%
df_history.salary.isnull().sum() # Usando el método isnull junto al sum podemos ver cuantos valores nulos hay en la columna salary.
# Out:
# 4238

# %% [markdown]
# Posteriormente analizaremos cuál es el impacto de estos nulos para decidir si hay que realizar imputaciones.

# %%
print(f"El porcentaje de valores nulos de la variable salary es de: {round((df_history.salary.isnull().sum()/df_history.shape[0])*100, 2)}%")
# Out:
# El porcentaje de valores nulos de la variable salary es de: 25.32%

# %%
df_history.salary = abs(df_history.salary) # Convertimos los valores a absolutos

# %%
df_history[df_history.salary < 0]['salary'] # Confirmamos que se ha realizado el cambio correctamente
# Out:
# Series([], Name: salary, dtype: float64)

# %%
# Verificamos si el cancellation_year y el cancellation_month corresponden a las mismas filas
df_hist_filtered = df_history[(df_history.cancellation_year.notnull()) & (df_history.cancellation_month.notnull())][['cancellation_year', 'cancellation_month']]
df_hist_filtered.shape
# Out:
# (2067, 2)

# %% [markdown]
# Como la cantidad de filas que teníamos para estas 2 variables era igual y como este conteo se mantiene al unir las 2 variables sin valores nulos, concluimos que las filas con valores se corresponden.
# * Concluimos que estos valores faltantes son clientes que no han cancelado el plan, mientras que los que tienen mes y año han cancelado el plan en esa fecha.

# %% [markdown]
# El Dataframe activity no tiene variables de tipo object, pero el history sí las tiene.

# %%
# Usamos el describe con el include = 'O' para ver las estadísticas descriptivas de las variables de tipo object. 
df_history.describe(include='O').T
# Out:
#                  count unique       top   freq
# country          16737      1    Canada  16737
# province         16737     11   Ontario   5404
# city             16737     29   Toronto   3351
# postal_code      16737     55   V6E 3D9    911
# gender           16737      2    Female   8410
# education        16737      5  Bachelor  10475
# marital_status   16737      3   Married   9735
# loyalty_card     16737      3      Star   7637
# enrollment_type  16737      2  Standard  15766

# %% [markdown]
# ### Conclusiones del describe para datos de tipo Object:
#
# * No hay valores nulos
# * Solo hay un País en la columna country, que es Canada. Esta columna no aporta infomación útil, por lo cuál será eliminada.

# %%
# Eliminamos la columna country del DataFrama ya que todos los valores son iguales usando el método drop de pandas con el parámetro inplace = True para aplicar el cambio en el DataFrame original.
df_history.drop(columns=['country'], inplace=True)

# %%
# Verificamos que la columna ha sido eliminada correctamente
df_history.columns
# Out:
# Index(['loyalty_number', 'province', 'city', 'postal_code', 'gender',
#        'education', 'salary', 'marital_status', 'loyalty_card', 'clv',
#        'enrollment_type', 'enrollment_year', 'enrollment_month',
#        'cancellation_year', 'cancellation_month'],
#       dtype='object')

# %%
# Verificamos si hay valores atípicos en las columnas de tipo object que tienen pocos valores únicos
columns = ['gender', 'education', 'marital_status', 'loyalty_card', 'enrollment_type']
for col in columns:
    display(df_history[col].value_counts())
# Out:
# gender
# Female    8410
# Male      8327
# Name: count, dtype: int64
# education
# Bachelor                10475
# College                  4238
# High School or Below      782
# Doctor                    734
# Master                    508
# Name: count, dtype: int64
# marital_status
# Married     9735
# Single      4484
# Divorced    2518
# Name: count, dtype: int64
# loyalty_card
# Star      7637
# Nova      5671
# Aurora    3429
# Name: count, dtype: int64
# enrollment_type
# Standard          15766
# 2018 Promotion      971
# Name: count, dtype: int64

# %% [markdown]
# De momento todos los valores son coherentes. Verificamos las demás columnas

# %%
df_history.province.value_counts()
# Out:
# province
# Ontario                 5404
# British Columbia        4409
# Quebec                  3300
# Alberta                  969
# Manitoba                 658
# New Brunswick            636
# Nova Scotia              518
# Saskatchewan             409
# Newfoundland             258
# Yukon                    110
# Prince Edward Island      66
# Name: count, dtype: int64

# %%
df_history.city.value_counts()
# Out:
# city
# Toronto           3351
# Vancouver         2582
# Montreal          2059
# Winnipeg           658
# Whistler           582
# Halifax            518
# Ottawa             509
# Trenton            486
# Edmonton           486
# Quebec City        485
# Dawson Creek       444
# Fredericton        425
# Regina             409
# Kingston           401
# Tremblant          398
# Victoria           389
# Hull               358
# West Vancouver     324
# St. John's         258
# Thunder Bay        256
# Sudbury            227
# Moncton            211
# Calgary            191
# Banff              179
# London             174
# Peace River        113
# Whitehorse         110
# Kelowna             88
# Charlottetown       66
# Name: count, dtype: int64

# %%
df_history.postal_code.value_counts()
# Out:
# postal_code
# V6E 3D9    911
# V5R 1W3    684
# V6T 1Y8    582
# V6E 3Z3    544
# M2M 7K8    534
# P1J 8T7    500
# H2T 9K8    499
# K8V 4B2    486
# G1B 3L5    485
# H2T 2J6    446
# U5I 4F1    444
# V1E 4R6    443
# E3B 2H2    425
# R2C 0M5    415
# M9K 2P4    401
# H5Y 2S9    398
# V10 6T5    389
# K1F 2R2    389
# H2Y 2W2    365
# J8Y 3Z5    358
# M8Y 4K8    340
# H4G 3T4    338
# B3J 9S2    329
# V6V 8Z3    324
# P2T 6G3    322
# H2Y 4R4    315
# M1R 4K3    313
# P1L 8X8    282
# P1W 1K4    275
# T9G 1W3    266
# A1C 6H9    258
# M2Z 4K1    257
# K8T 5M5    256
# P5S 6R4    246
# M5V 1G5    227
# S6J 3G0    226
# T3G 6Y6    220
# E1A 2A7    211
# T3E 2V9    191
# B3C 2M8    189
# S1J 3C5    183
# T4V 1D4    179
# M5B 3E4    174
# M2M 6J7    153
# R6Y 4T5    143
# M2P 4F6    126
# K1G 4Z0    120
# T9O 2W2    113
# Y2K 6R0    110
# R3R 3T4    100
# H3T 8L4     89
# V09 2E9     88
# C1A 6E8     66
# H3J 5I6      7
# M3R 4K8      3
# Name: count, dtype: int64

# %%
# El método duplicated asociado al sum y aplicado a un DataFrame nos permite verificar si hay filas duplicadas en el DataFrame
df_activity.duplicated().sum()
# Out:
# 1864

# %%
df_history.duplicated().sum()
# Out:
# 0

# %%
# El método isna asociado al sum aplicado a un DataFrame nos permite verificar el conteo de valores nulos por columna.
df_activity.isna().sum()
# Out:
# loyalty_number                 0
# year                           0
# month                          0
# flights_booked                 0
# flights_with_companions        0
# total_flights                  0
# distance                       0
# points_accumulated             0
# points_redeemed                0
# dollar_cost_points_redeemed    0
# dtype: int64

# %%
df_history.isna().sum()
# Out:
# loyalty_number            0
# province                  0
# city                      0
# postal_code               0
# gender                    0
# education                 0
# salary                 4238
# marital_status            0
# loyalty_card              0
# clv                       0
# enrollment_type           0
# enrollment_year           0
# enrollment_month          0
# cancellation_year     14670
# cancellation_month    14670
# dtype: int64

# %%
# Con este bucle for verificamos la cantidad de valores duplicados por columna en el DataFrame activity
for col in df_activity.columns:
    print(f"{col} - {df_activity[col].duplicated().sum()}")
# Out:
# loyalty_number - 388887
# year - 405622
# month - 405612
# flights_booked - 405602
# flights_with_companions - 405612
# total_flights - 405591
# distance - 400878
# points_accumulated - 404075
# points_redeemed - 405037
# dollar_cost_points_redeemed - 405575

# %%
# Con este bucle for verificamos la cantidad de valores duplicados por columna en el DataFrame history
for col in df_history.columns:
    print(f"{col} - {df_history[col].duplicated().sum()}")
# Out:
# loyalty_number - 0
# province - 16726
# city - 16708
# postal_code - 16682
# gender - 16735
# education - 16732
# salary - 10846
# marital_status - 16734
# loyalty_card - 16734
# clv - 8753
# enrollment_type - 16735
# enrollment_year - 16730
# enrollment_month - 16725
# cancellation_year - 16730
# cancellation_month - 16724

# %%
# Con este bucle for verificamos el conteo de valores únicos por columna en el DataFrame activity
for col in df_activity.columns:
    print(f"{col} - {df_activity[col].nunique()}")
# Out:
# loyalty_number - 16737
# year - 2
# month - 12
# flights_booked - 22
# flights_with_companions - 12
# total_flights - 33
# distance - 4746
# points_accumulated - 1549
# points_redeemed - 587
# dollar_cost_points_redeemed - 49

# %%
# Con este bucle for verificamos el conteo de valores únicos por columna en el DataFrame history
for col in df_history.columns:
    print(f"{col} - {df_history[col].nunique()}")
# Out:
# loyalty_number - 16737
# province - 11
# city - 29
# postal_code - 55
# gender - 2
# education - 5
# salary - 5890
# marital_status - 3
# loyalty_card - 3
# clv - 7984
# enrollment_type - 2
# enrollment_year - 7
# enrollment_month - 12
# cancellation_year - 6
# cancellation_month - 12

# %% [markdown]
# ### Nos damos cuenta de que el conteo de los números únicos de la columna loyalty_number en los 2 conjuntos de datos son iguales.

# %%
df_activity.loyalty_number.nunique()
# Out:
# 16737

# %%
df_history.loyalty_number.nunique()
# Out:
# 16737

# %% [markdown]
# Buscamos entender el significado de los valores duplicados en activity para la columna loyalty_number

# %%
df_activity.loyalty_number.value_counts()
# Out:
# loyalty_number
# 678205    72
# 989528    48
# 373638    48
# 684889    48
# 684881    48
#           ..
# 428526    24
# 428536    24
# 428565    24
# 428590    24
# 999891    24
# Name: count, Length: 16737, dtype: int64

# %% [markdown]
# Vemos que los valores unicos estraídos del value counts de esta columna son 3.

# %%
df_activity.loyalty_number.value_counts().unique()
# Out:
# array([72, 48, 24])

# %% [markdown]
# Intentamos buscar una explicación
#
# Filtramos el DataFrame por el loyalty_number que mas se repite y miramos los resultados

# %%
df_activity[df_activity.loyalty_number == 678205].sort_values(by=['year', 'month'])[:10]
# Vemos que para este cliente que se repite 72 veces, hay 3 filas para cada mes, o sea, 12 meses al año x 3 filas = 36, x 2 años = 72.
# Out:
#        loyalty_number  year  month  flights_booked  flights_with_companions  \
# 10862          678205  2017      1               0                        0
# 10863          678205  2017      1               0                        0
# 10864          678205  2017      1               0                        0
# 27763          678205  2017      2               0                        0
# 27764          678205  2017      2               0                        0
# 27765          678205  2017      2               0                        0
# 44664          678205  2017      3               0                        0
# 44665          678205  2017      3               0                        0
# 44666          678205  2017      3               0                        0
# 61565          678205  2017      4               0                        0
#
#        total_flights  distance  points_accumulated  points_redeemed  \
# 10862              0         0                 0.0                0
# 10863              0         0                 0.0                0
# 10864              0         0                 0.0                0
# 27763              0         0                 0.0                0
# 27764              0         0                 0.0                0
# 27765              0         0                 0.0                0
# 44664              0         0                 0.0                0
# 44665              0         0                 0.0                0
# 44666              0         0                 0.0                0
# 61565              0         0                 0.0                0
#
#        dollar_cost_points_redeemed
# 10862                            0
# 10863                            0
# 10864                            0
# 27763                            0
# 27764                            0
# 27765                            0
# 44664                            0
# 44665                            0
# 44666                            0
# 61565                            0

# %% [markdown]
# Ahora veamos que ocurre con un loyalty number que repite 48 veces

# %%
df_activity[df_activity.loyalty_number == 989528].sort_values(by=['year', 'month'])[:10]
# Vemos que para este cliente que se repite 48 veces, hay 2 filas para cada mes, o sea, 12 meses al año x 2 filas = 24, x 2 años = 48.
# Out:
#        loyalty_number  year  month  flights_booked  flights_with_companions  \
# 16713          989528  2017      1               0                        0
# 16714          989528  2017      1               0                        0
# 33614          989528  2017      2               0                        0
# 33615          989528  2017      2               0                        0
# 50515          989528  2017      3               0                        0
# 50516          989528  2017      3               0                        0
# 67416          989528  2017      4               0                        0
# 67417          989528  2017      4               0                        0
# 84317          989528  2017      5               0                        0
# 84318          989528  2017      5               0                        0
#
#        total_flights  distance  points_accumulated  points_redeemed  \
# 16713              0         0                 0.0                0
# 16714              0         0                 0.0                0
# 33614              0         0                 0.0                0
# 33615              0         0                 0.0                0
# 50515              0         0                 0.0                0
# 50516              0         0                 0.0                0
# 67416              0         0                 0.0                0
# 67417              0         0                 0.0                0
# 84317              0         0                 0.0                0
# 84318              0         0                 0.0                0
#
#        dollar_cost_points_redeemed
# 16713                            0
# 16714                            0
# 33614                            0
# 33615                            0
# 50515                            0
# 50516                            0
# 67416                            0
# 67417                            0
# 84317                            0
# 84318                            0

# %% [markdown]
# Ahora veamos que ocurre con un loyalty number que repite 24 veces

# %%
df_activity[df_activity.loyalty_number == 428526].sort_values(by=['year', 'month'])[:10]
# Vemos que para este cliente que se repite 24 veces, hay 1 fila para cada mes, o sea, 12 meses al año x 1 filas = 12, x 2 años = 24.
# Out:
#         loyalty_number  year  month  flights_booked  flights_with_companions  \
# 6130            428526  2017      1              12                        3
# 23031           428526  2017      2               0                        0
# 39932           428526  2017      3               0                        0
# 56833           428526  2017      4               0                        0
# 73734           428526  2017      5               0                        0
# 90635           428526  2017      6               0                        0
# 390119          428526  2017      7              13                        5
# 124437          428526  2017      8               0                        0
# 141338          428526  2017      9              15                        0
# 158239          428526  2017     10               7                        0
#
#         total_flights  distance  points_accumulated  points_redeemed  \
# 6130               15      3105               310.0                0
# 23031               0         0                 0.0                0
# 39932               0         0                 0.0                0
# 56833               0         0                 0.0                0
# 73734               0         0                 0.0                0
# 90635               0         0                 0.0                0
# 390119             18      1350               135.0              677
# 124437              0         0                 0.0                0
# 141338             15      2025               202.0                0
# 158239              7       798                79.0                0
#
#         dollar_cost_points_redeemed
# 6130                              0
# 23031                             0
# 39932                             0
# 56833                             0
# 73734                             0
# 90635                             0
# 390119                           55
# 124437                            0
# 141338                            0
# 158239                            0

# %% [markdown]
# * Parece tratarse de un seguimiento mensual de la actividad de los clientes. Las filas con valores 0 indican que en estos meses el cliente no tuvo cambios en su actividad.
# * También vemos que parece haber un seguimiento que ocurre 1, 2 o 3 veces al mes para actualizar los datos de la actividad de los clientes.

# %% [markdown]
# Vamos a buscar diferencias entre estos 3 tipos de cliente para ver si encontramos algun patrón

# %%
clients = [678205, 989528, 428526]
df_history[(df_history.loyalty_number == 678205) | (df_history.loyalty_number == 989528) | (df_history.loyalty_number == 428526)]
# Out:
#       loyalty_number province      city postal_code  gender education  \
# 5022          989528   Quebec  Montreal     H2T 2J6  Female   College
# 7608          428526  Ontario   Toronto     P2T 6G3    Male   College
# 9490          678205   Quebec      Hull     J8Y 3Z5    Male  Bachelor
#
#        salary marital_status loyalty_card       clv enrollment_type  \
# 5022      NaN       Divorced         Nova   3370.07        Standard
# 7608      NaN        Married         Nova   7374.08        Standard
# 9490  67358.0        Married         Nova  20230.97        Standard
#
#       enrollment_year  enrollment_month  cancellation_year  cancellation_month
# 5022             2017                 5                NaN                 NaN
# 7608             2018                11                NaN                 NaN
# 9490             2015                 9                NaN                 NaN

# %% [markdown]
# Quizás estos duplicados puedan estar realcionados con el loyalty_card y el enrollment_type, el análisis podría seguir por este camino, pero antes, veremos el porcentaje de datos atípicos dentro del conjunto para decidir si merece la pena profundizar por este camino.

# %% [markdown]
# Calculamos el porcentaje de estos 3 valores dentro del conjunto de datos

# %%
round((df_activity.loyalty_number.value_counts().value_counts()/df_activity.loyalty_number.nunique())*100, 2)
# Out:
# count
# 24    99.03
# 48     0.97
# 72     0.01
# Name: count, dtype: float64

# %% [markdown]
# * Vemos que el seguimiento mensual que ocurre 1 vez al mes es dominante
# * Ya que hay un grupo dominante del seguimiento de la actividad que ocurre 1 vez al mes y los demás grupos tienen un porcentaje muy bajo, vamos a buscar un patrón para eliminar los duplicados y patronizar los datos.

# %%
loyalty_counts = df_activity.loyalty_number.value_counts()

# Identificar los loyalty_number con 48 y 72 ocurrencias
loyalty_48_72 = loyalty_counts[(loyalty_counts == 48) | (loyalty_counts == 72)].index

# Filtrar el DataFrame para obtener solo los registros de estos loyalty_number
df_loyalty_48_72 = df_activity[df_activity.loyalty_number.isin(loyalty_48_72)]
df_loyalty_48_72.sort_values(by=['loyalty_number', 'year', 'month'])[10:15]
# Out:
#         loyalty_number  year  month  flights_booked  flights_with_companions  \
# 84546           101902  2017      6              10                        5
# 84547           101902  2017      6               9                        0
# 101447          101902  2017      7               0                        0
# 101448          101902  2017      7               0                        0
# 118348          101902  2017      8              17                        0
#
#         total_flights  distance  points_accumulated  points_redeemed  \
# 84546              15      3015               301.0                0
# 84547               9      1521               152.0                0
# 101447              0         0                 0.0                0
# 101448              0         0                 0.0                0
# 118348             17      3893               389.0                0
#
#         dollar_cost_points_redeemed
# 84546                             0
# 84547                             0
# 101447                            0
# 101448                            0
# 118348                            0

# %% [markdown]
# * Hemos buscado un patrón para decidir las filas a eliminar pero no hay una posible razón que confirme esta decisión, así que decidimos hacer un drop duplicates para este grupo sabiendo que representan el 1% del total. De esta menera mantendremos todos los loyalty_numbers en el análisis ya que tienen relación con el df_history.

# %%
# Verificamos la cantidade de datos
df_activity.shape
# Out:
# (405624, 10)

# %%
# Eliminamos duplicados quedándonos con la última ocurrencia por cada combinación de loyalty_number, year y month
df_activity_cleaned = df_activity.drop_duplicates(subset=['loyalty_number', 'year', 'month'], keep='last')
df_activity_cleaned.shape
# Out:
# (401688, 10)

# %%
# Verificamos que tenemos 24 ocurrencias para cada loyalty_number
df_activity_cleaned.loyalty_number.value_counts()
# Out:
# loyalty_number
# 100018    24
# 762446    24
# 762485    24
# 762562    24
# 762671    24
#           ..
# 427444    24
# 427733    24
# 427804    24
# 427919    24
# 999891    24
# Name: count, Length: 16737, dtype: int64

# %%
# Verificamos que no se han eliminado loyalty_numbers
df_activity_cleaned.loyalty_number.nunique() == df_history.loyalty_number.nunique()
# Out:
# True

# %% [markdown]
# * Hemos investigado cuál puede ser el significado de la métrica CLV
# * En el contexto de análisis de datos de clientes, CLV generalmente significa Customer Lifetime Value (Valor del Tiempo de Vida del Cliente). Es una métrica que estima el valor total que un cliente aportará a la empresa durante toda su relación con la misma. Este valor se calcula teniendo en cuenta diversos factores como los ingresos generados por el cliente, los costos de adquisición, los costos de servicio, y la duración estimada de la relación con el cliente.
# * Valor monetario: El CLV probablemente está expresado en términos monetarios, lo que indica el valor total en dinero que se espera que el cliente aporte a lo largo de su relación con la empresa.

# %% [markdown]
# Para concluir las transformaciones de los datos, investigaremos los valores nulos de la métrica salary

# %%
df_history[df_history.salary.isnull()][0:50]

# %% [markdown]
# Parece ser que los nulos de la métrica salary están relacionados con la variable education, ya que todos parecen ser College, vamos a confirmar esta suposición.

# %%
# Primero, filtramos el DataFrame para obtener solo las filas donde 'Education' es 'College'
df_history[df_history.education == 'College'].salary.isnull().sum()
# Out:
# 4238

# %% [markdown]
# Calculamos la cantidad de valores nulos en 'Salary' para este subconjunto y comparamos con la cantidad de nulos de salary en el dataframe no filtrado.

# %%
df_history.salary.isnull().sum()
# Out:
# 4238

# %% [markdown]
# Podemos confirmar que los valores nulos en salary están 100% relacionados con el nivel de educación 'College', ya que los estudiantes no suelen tener salarios.

# %% [markdown]
# Ahora vamos a unir los 2 conjuntos de datos: Queremos mantener toda la información de los vuelos, lo que significa tener 24 loyalty_number por cliente unido al df_history que tienen sus loyalty_number unicos.

# %%
# Realizamos la unión con merge, que se utiliza para hacer uniones por columnas y con el parámetro how=left, muy similar al SQL, nos devuelve todos los datos.
df_combinado = pd.merge(df_activity_cleaned, df_history, on='loyalty_number', how='left')

# %% [markdown]
# Nos aseguramos de que el mergeo ocurrió correctamente

# %%
df_combinado.sort_values(by=['loyalty_number', 'year', 'month']).head(25)
# Out:
#         loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0               100018  2017      1               3                        0
# 16713           100018  2017      2               2                        2
# 211161          100018  2017      3              14                        3
# 50165           100018  2017      4               4                        0
# 66887           100018  2017      5               0                        0
# 83623           100018  2017      6               4                        1
# 100358          100018  2017      7              10                        0
# 141336          100018  2017      8              10                        5
# 133833          100018  2017      9               9                        4
# 150579          100018  2017     10               6                        0
# 167317          100018  2017     11              13                        1
# 184035          100018  2017     12               6                        0
# 200778          100018  2018      1               1                        0
# 254779          100018  2018      2               6                        0
# 254558          100018  2018      3               7                        0
# 264391          100018  2018      4               5                        0
# 267721          100018  2018      5               0                        0
# 284423          100018  2018      6               0                        0
# 301175          100018  2018      7               9                        7
# 317927          100018  2018      8               0                        0
# 334660          100018  2018      9              14                        2
# 45881           100018  2018     10               6                        4
# 368177          100018  2018     11              11                        0
# 384922          100018  2018     12              17                        6
# 1               100102  2017      1              10                        4
#
#         total_flights  distance  points_accumulated  points_redeemed  \
# 0                   3      1521               152.0                0
# 16713               4      1320               132.0                0
# 211161             17      2533               253.0              438
# 50165               4       924                92.0                0
# 66887               0         0                 0.0                0
# 83623               5      4330               433.0                0
# 100358             10      3870               387.0                0
# 141336             15      4200               420.0              690
# 133833             13      1651               165.0                0
# 150579              6      1032               103.0                0
# 167317             14      3374               337.0                0
# 184035              6      1908               190.0                0
# 200778              1       312                31.0                0
# 254779              6      1824               273.0                0
# 254558              7      1876               280.5                0
# 264391              5      2590               388.5                0
# 267721              0         0                 0.0                0
# 284423              0         0                 0.0                0
# 301175             16      2736               273.0                0
# 317927              0         0                 0.0                0
# 334660             16      3568               356.0                0
# 45881              10      3110               311.0              385
# 368177             11      3058               305.0                0
# 384922             23      4945               494.0                0
# 1                  14      2030               203.0                0
#
#         dollar_cost_points_redeemed province      city postal_code  gender  \
# 0                                 0  Alberta  Edmonton     T9G 1W3  Female
# 16713                             0  Alberta  Edmonton     T9G 1W3  Female
# 211161                           36  Alberta  Edmonton     T9G 1W3  Female
# 50165                             0  Alberta  Edmonton     T9G 1W3  Female
# 66887                             0  Alberta  Edmonton     T9G 1W3  Female
# 83623                             0  Alberta  Edmonton     T9G 1W3  Female
# 100358                            0  Alberta  Edmonton     T9G 1W3  Female
# 141336                           56  Alberta  Edmonton     T9G 1W3  Female
# 133833                            0  Alberta  Edmonton     T9G 1W3  Female
# 150579                            0  Alberta  Edmonton     T9G 1W3  Female
# 167317                            0  Alberta  Edmonton     T9G 1W3  Female
# 184035                            0  Alberta  Edmonton     T9G 1W3  Female
# 200778                            0  Alberta  Edmonton     T9G 1W3  Female
# 254779                            0  Alberta  Edmonton     T9G 1W3  Female
# 254558                            0  Alberta  Edmonton     T9G 1W3  Female
# 264391                            0  Alberta  Edmonton     T9G 1W3  Female
# 267721                            0  Alberta  Edmonton     T9G 1W3  Female
# 284423                            0  Alberta  Edmonton     T9G 1W3  Female
# 301175                            0  Alberta  Edmonton     T9G 1W3  Female
# 317927                            0  Alberta  Edmonton     T9G 1W3  Female
# 334660                            0  Alberta  Edmonton     T9G 1W3  Female
# 45881                            31  Alberta  Edmonton     T9G 1W3  Female
# 368177                            0  Alberta  Edmonton     T9G 1W3  Female
# 384922                            0  Alberta  Edmonton     T9G 1W3  Female
# 1                                 0  Ontario   Toronto     M1R 4K3    Male
#
#        education   salary marital_status loyalty_card      clv  \
# 0       Bachelor  92552.0        Married       Aurora  7919.20
# 16713   Bachelor  92552.0        Married       Aurora  7919.20
# 211161  Bachelor  92552.0        Married       Aurora  7919.20
# 50165   Bachelor  92552.0        Married       Aurora  7919.20
# 66887   Bachelor  92552.0        Married       Aurora  7919.20
# 83623   Bachelor  92552.0        Married       Aurora  7919.20
# 100358  Bachelor  92552.0        Married       Aurora  7919.20
# 141336  Bachelor  92552.0        Married       Aurora  7919.20
# 133833  Bachelor  92552.0        Married       Aurora  7919.20
# 150579  Bachelor  92552.0        Married       Aurora  7919.20
# 167317  Bachelor  92552.0        Married       Aurora  7919.20
# 184035  Bachelor  92552.0        Married       Aurora  7919.20
# 200778  Bachelor  92552.0        Married       Aurora  7919.20
# 254779  Bachelor  92552.0        Married       Aurora  7919.20
# 254558  Bachelor  92552.0        Married       Aurora  7919.20
# 264391  Bachelor  92552.0        Married       Aurora  7919.20
# 267721  Bachelor  92552.0        Married       Aurora  7919.20
# 284423  Bachelor  92552.0        Married       Aurora  7919.20
# 301175  Bachelor  92552.0        Married       Aurora  7919.20
# 317927  Bachelor  92552.0        Married       Aurora  7919.20
# 334660  Bachelor  92552.0        Married       Aurora  7919.20
# 45881   Bachelor  92552.0        Married       Aurora  7919.20
# 368177  Bachelor  92552.0        Married       Aurora  7919.20
# 384922  Bachelor  92552.0        Married       Aurora  7919.20
# 1        College      NaN         Single         Nova  2887.74
#
#        enrollment_type  enrollment_year  enrollment_month  cancellation_year  \
# 0             Standard             2016                 8                NaN
# 16713         Standard             2016                 8                NaN
# 211161        Standard             2016                 8                NaN
# 50165         Standard             2016                 8                NaN
# 66887         Standard             2016                 8                NaN
# 83623         Standard             2016                 8                NaN
# 100358        Standard             2016                 8                NaN
# 141336        Standard             2016                 8                NaN
# 133833        Standard             2016                 8                NaN
# 150579        Standard             2016                 8                NaN
# 167317        Standard             2016                 8                NaN
# 184035        Standard             2016                 8                NaN
# 200778        Standard             2016                 8                NaN
# 254779        Standard             2016                 8                NaN
# 254558        Standard             2016                 8                NaN
# 264391        Standard             2016                 8                NaN
# 267721        Standard             2016                 8                NaN
# 284423        Standard             2016                 8                NaN
# 301175        Standard             2016                 8                NaN
# 317927        Standard             2016                 8                NaN
# 334660        Standard             2016                 8                NaN
# 45881         Standard             2016                 8                NaN
# 368177        Standard             2016                 8                NaN
# 384922        Standard             2016                 8                NaN
# 1             Standard             2013                 3                NaN
#
#         cancellation_month
# 0                      NaN
# 16713                  NaN
# 211161                 NaN
# 50165                  NaN
# 66887                  NaN
# 83623                  NaN
# 100358                 NaN
# 141336                 NaN
# 133833                 NaN
# 150579                 NaN
# 167317                 NaN
# 184035                 NaN
# 200778                 NaN
# 254779                 NaN
# 254558                 NaN
# 264391                 NaN
# 267721                 NaN
# 284423                 NaN
# 301175                 NaN
# 317927                 NaN
# 334660                 NaN
# 45881                  NaN
# 368177                 NaN
# 384922                 NaN
# 1                      NaN

# %% [markdown]
# Vemos que hay 24 filas para el primer loyalty_number usando el head(25) y ahora vemos con el tail(25) que hay 24 valores para el último loyalty_number

# %%
df_combinado.sort_values(by=['loyalty_number', 'year', 'month']).tail(25)
# Out:
#         loyalty_number  year  month  flights_booked  flights_with_companions  \
# 401686          999982  2018     12               0                        0
# 16712           999986  2017      1               1                        0
# 33449           999986  2017      2               7                        0
# 50164           999986  2017      3              13                        3
# 273641          999986  2017      4               5                        4
# 83622           999986  2017      5              13                        0
# 100357          999986  2017      6               0                        0
# 117095          999986  2017      7               0                        0
# 133832          999986  2017      8              12                        0
# 150578          999986  2017      9               9                        0
# 167316          999986  2017     10              12                        0
# 184034          999986  2017     11               0                        0
# 200777          999986  2017     12               0                        0
# 217498          999986  2018      1               0                        0
# 251607          999986  2018      2               4                        3
# 263355          999986  2018      3               5                        2
# 267720          999986  2018      4               0                        0
# 284422          999986  2018      5               0                        0
# 301174          999986  2018      6               0                        0
# 317926          999986  2018      7              15                        0
# 139322          999986  2018      8               8                        1
# 351410          999986  2018      9               0                        0
# 368176          999986  2018     10               6                        0
# 384921          999986  2018     11              11                        4
# 401687          999986  2018     12               0                        0
#
#         total_flights  distance  points_accumulated  points_redeemed  \
# 401686              0         0                 0.0                0
# 16712               1      1849               184.0                0
# 33449               7      3017               301.0                0
# 50164              16      3856               385.0                0
# 273641              9      1845               184.0              527
# 83622              13      1352               135.0                0
# 100357              0         0                 0.0                0
# 117095              0         0                 0.0                0
# 133832             12      1716               171.0                0
# 150578              9      2781               278.0                0
# 167316             12      2856               285.0                0
# 184034              0         0                 0.0                0
# 200777              0         0                 0.0                0
# 217498              0         0                 0.0                0
# 251607              7      1967               245.0              544
# 263355              7      3283               410.0                0
# 267720              0         0                 0.0                0
# 284422              0         0                 0.0                0
# 301174              0         0                 0.0                0
# 317926             15      1995               199.0                0
# 139322              9      3672               367.0              655
# 351410              0         0                 0.0                0
# 368176              6       708                70.0                0
# 384921             15      2040               204.0                0
# 401687              0         0                 0.0                0
#
#         dollar_cost_points_redeemed          province      city postal_code  \
# 401686                            0  British Columbia  Victoria     V10 6T5
# 16712                             0           Ontario    Ottawa     K1F 2R2
# 33449                             0           Ontario    Ottawa     K1F 2R2
# 50164                             0           Ontario    Ottawa     K1F 2R2
# 273641                           43           Ontario    Ottawa     K1F 2R2
# 83622                             0           Ontario    Ottawa     K1F 2R2
# 100357                            0           Ontario    Ottawa     K1F 2R2
# 117095                            0           Ontario    Ottawa     K1F 2R2
# 133832                            0           Ontario    Ottawa     K1F 2R2
# 150578                            0           Ontario    Ottawa     K1F 2R2
# 167316                            0           Ontario    Ottawa     K1F 2R2
# 184034                            0           Ontario    Ottawa     K1F 2R2
# 200777                            0           Ontario    Ottawa     K1F 2R2
# 217498                            0           Ontario    Ottawa     K1F 2R2
# 251607                           44           Ontario    Ottawa     K1F 2R2
# 263355                            0           Ontario    Ottawa     K1F 2R2
# 267720                            0           Ontario    Ottawa     K1F 2R2
# 284422                            0           Ontario    Ottawa     K1F 2R2
# 301174                            0           Ontario    Ottawa     K1F 2R2
# 317926                            0           Ontario    Ottawa     K1F 2R2
# 139322                           53           Ontario    Ottawa     K1F 2R2
# 351410                            0           Ontario    Ottawa     K1F 2R2
# 368176                            0           Ontario    Ottawa     K1F 2R2
# 384921                            0           Ontario    Ottawa     K1F 2R2
# 401687                            0           Ontario    Ottawa     K1F 2R2
#
#         gender education   salary marital_status loyalty_card      clv  \
# 401686    Male   College      NaN        Married         Star  2631.56
# 16712   Female  Bachelor  46594.0        Married         Nova  8257.01
# 33449   Female  Bachelor  46594.0        Married         Nova  8257.01
# 50164   Female  Bachelor  46594.0        Married         Nova  8257.01
# 273641  Female  Bachelor  46594.0        Married         Nova  8257.01
# 83622   Female  Bachelor  46594.0        Married         Nova  8257.01
# 100357  Female  Bachelor  46594.0        Married         Nova  8257.01
# 117095  Female  Bachelor  46594.0        Married         Nova  8257.01
# 133832  Female  Bachelor  46594.0        Married         Nova  8257.01
# 150578  Female  Bachelor  46594.0        Married         Nova  8257.01
# 167316  Female  Bachelor  46594.0        Married         Nova  8257.01
# 184034  Female  Bachelor  46594.0        Married         Nova  8257.01
# 200777  Female  Bachelor  46594.0        Married         Nova  8257.01
# 217498  Female  Bachelor  46594.0        Married         Nova  8257.01
# 251607  Female  Bachelor  46594.0        Married         Nova  8257.01
# 263355  Female  Bachelor  46594.0        Married         Nova  8257.01
# 267720  Female  Bachelor  46594.0        Married         Nova  8257.01
# 284422  Female  Bachelor  46594.0        Married         Nova  8257.01
# 301174  Female  Bachelor  46594.0        Married         Nova  8257.01
# 317926  Female  Bachelor  46594.0        Married         Nova  8257.01
# 139322  Female  Bachelor  46594.0        Married         Nova  8257.01
# 351410  Female  Bachelor  46594.0        Married         Nova  8257.01
# 368176  Female  Bachelor  46594.0        Married         Nova  8257.01
# 384921  Female  Bachelor  46594.0        Married         Nova  8257.01
# 401687  Female  Bachelor  46594.0        Married         Nova  8257.01
#
#        enrollment_type  enrollment_year  enrollment_month  cancellation_year  \
# 401686        Standard             2018                 7                NaN
# 16712   2018 Promotion             2018                 2                NaN
# 33449   2018 Promotion             2018                 2                NaN
# 50164   2018 Promotion             2018                 2                NaN
# 273641  2018 Promotion             2018                 2                NaN
# 83622   2018 Promotion             2018                 2                NaN
# 100357  2018 Promotion             2018                 2                NaN
# 117095  2018 Promotion             2018                 2                NaN
# 133832  2018 Promotion             2018                 2                NaN
# 150578  2018 Promotion             2018                 2                NaN
# 167316  2018 Promotion             2018                 2                NaN
# 184034  2018 Promotion             2018                 2                NaN
# 200777  2018 Promotion             2018                 2                NaN
# 217498  2018 Promotion             2018                 2                NaN
# 251607  2018 Promotion             2018                 2                NaN
# 263355  2018 Promotion             2018                 2                NaN
# 267720  2018 Promotion             2018                 2                NaN
# 284422  2018 Promotion             2018                 2                NaN
# 301174  2018 Promotion             2018                 2                NaN
# 317926  2018 Promotion             2018                 2                NaN
# 139322  2018 Promotion             2018                 2                NaN
# 351410  2018 Promotion             2018                 2                NaN
# 368176  2018 Promotion             2018                 2                NaN
# 384921  2018 Promotion             2018                 2                NaN
# 401687  2018 Promotion             2018                 2                NaN
#
#         cancellation_month
# 401686                 NaN
# 16712                  NaN
# 33449                  NaN
# 50164                  NaN
# 273641                 NaN
# 83622                  NaN
# 100357                 NaN
# 117095                 NaN
# 133832                 NaN
# 150578                 NaN
# 167316                 NaN
# 184034                 NaN
# 200777                 NaN
# 217498                 NaN
# 251607                 NaN
# 263355                 NaN
# 267720                 NaN
# 284422                 NaN
# 301174                 NaN
# 317926                 NaN
# 139322                 NaN
# 351410                 NaN
# 368176                 NaN
# 384921                 NaN
# 401687                 NaN

# %% [markdown]
# Confirmamos que la cantidad de filas que teníamos anteriormente en el df_activity_cleaned es la misma que tenemos ahora en el df_combinado y también podemos afirmar que los valores mínimo y máximo para el loyalty_number que hemos visto en el describe están incluidos en el df_combinado.

# %%
df_activity_cleaned.shape[0] == df_combinado.shape[0]
# Out:
# True

# %%
# Guardamos los datos tratados para uso en fases posteriores del análisis
df_activity_cleaned.to_csv('../data/df_activity.csv')
df_history.to_csv('../data/df_history.csv')
df_combinado.to_csv('../data/df_combined.csv')

# %% [markdown]
# Damos por concluída la primera fase de exploración y transformación de los datos.
